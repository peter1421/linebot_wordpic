# %%
import requests
from bs4 import BeautifulSoup
# from fake_useragent import UserAgent
import random
import re
import pandas

def get_root(url):
    try:
        try:
            response = requests.get(url,timeout=5)
            root = BeautifulSoup(response.text, "html.parser")
            return root
        except:    
            ua = UserAgent().chrome
            response = requests.get(url, headers={"user-agent": ua}, timeout=5)
            root = BeautifulSoup(response.text, "html.parser")
            return root
    except:    
        res = requests.get('https://free-proxy-list.net/')
        m = re.findall('\d+\.\d+\.\d+\.\d+:\d+', res.text)
        for ip in m:
            try:
                ua = UserAgent().chrome
                response = requests.get(
                    url, headers={"user-agent": ua}, proxies={'http': ip, 'https': ip}, timeout=5)
                print(response, ip)
                if(response.ok):
                    print("ok")
                    root = BeautifulSoup(response.text, "html.parser")
                    return root
                else:
                    continue
            except:
                print('FAIL', ip)
        return 0



def get_txt(root):
    ans = []
    head = 'https://tw.appledaily.com/'
    floor = root.find_all("div", class_="flex-feature")
    for x in floor:
        temp = []
        link = head+(x.find("a", class_="story-card")['href'])
        title = x.find("span", class_="headline truncate truncate--3").text
        temp = [title, link]
        ans.append(temp)
    return ans


def get_list():
    url='https://tw.appledaily.com/home/'
    root=get_root(url)
    w=get_txt(root)
    for x in w:
        print("標題:{}\n網址:{}\n\n".format(x[0],x[1]))
    return w 
    
df = pandas.DataFrame(get_list())
# Out:
# 標題:劉寶傑：民進黨派「沒念過大學的傢伙」推國產疫苗　鄉民猜在講他
# 網址:https://tw.appledaily.com//life/20210601/GRGYZOQN6ZHCDAP2VH56PUXFJY/
#
#
# 標題:蘋果查真相｜網瘋傳陳時中造謠「莫德納二期收660人」　追查鄉民說「8千人」臉腫大了
# 網址:https://tw.appledaily.com//life/20210601/JABA5U2M5ZBUVDGY3AOU53GXIE/
#
#
# 標題:確診者砍3醫護｜揮刀濺血瞬間「醫護正在做CPR」　好慘！只能拿鉛板當盾牌
# 網址:https://tw.appledaily.com//local/20210601/B44HOFYPRNEUXDGSYL7ZRDE6G4/
#
#
# 標題:確診者砍3醫護｜雙和護理師「右手韌帶斷」生涯恐毀　醫怒：請嚴懲重罰
# 網址:https://tw.appledaily.com//local/20210601/33AUDVIZL5CVZHZRCHDRXC3FBA/
#
#
# 標題:《蘋果》追播毒｜小姐奔逃南台call恩客　老司機「擋不住性慾」夜夜尋芳
# 網址:https://tw.appledaily.com//local/20210601/VDVSUBKIIBGQLN3VQXW3G5OVCQ/
#
#
# 標題:張小燕求疫苗「台灣人的命也是命」　謝志偉反嗆：說得好，可惜晚了幾十年
# 網址:https://tw.appledaily.com//politics/20210601/DVBBHCVHUVHWFBWAJLXVE4RED4/
#
#
# 標題:女繳1800萬保費一年後死亡　富邦人壽拒理賠！業務挨告詐欺
# 網址:https://tw.appledaily.com//local/20210531/YWAGUA3BLRDR3OOPCIYCUKJZSA/
#
#
# 標題:全公司在家上班付全薪！親戚都想來　486先生：直接拒絕不錄用
#
#
# 標題:三重確診郵差曝3處感染源　吃清冠1號不頭痛但高燒拉水便
# 網址:https://tw.appledaily.com//life/20210531/2M4QQLKDYNG2HPSUZJC3ZT4Z2U/
#
#
# 標題:噁到爆！菜包吃兩口　驚見裡面一顆老鼠頭瞪著自己
# 網址:https://tw.appledaily.com//international/20210601/RGZWKVRJBJCUHD6T7SKVERV7WQ/
#
#
# 標題:爭議人物｜范綱皓負責綠營社群不到1年兩度惹議　倡性平不諱言「個性陰柔被笑娘」
# 網址:https://tw.appledaily.com//politics/20210601/N5J6GUCS45GUVCEVHYSMSY5G6Q/
#
#
# 標題:台中狂徒搶奪落單女座車　死巷撞警車突圍逃逸
# 網址:https://tw.appledaily.com//local/20210601/WM5GHH6VHZD5RMOIK7IVLZ4KZI/
#
#
# 標題:「有共不辱，愧對父母」！波特王出品粉紅退散款口罩　聽見玻璃心碎滿地
# 網址:https://tw.appledaily.com//life/20210601/FJ3LAW2EANCDVGDSENBRY7YYG4/
#
#
# 標題:蔡英文直播6重點　鄉民「翻譯」要你反著看就懂了
# 網址:https://tw.appledaily.com//politics/20210531/RO3PGLE55VDWTGTGQSBQAUWLPE/
#
#
# 標題:法網｜NBA眾球星聲援大坂直美　李拉德：給予我最大的尊敬
# 網址:https://tw.appledaily.com//sports/20210601/UUWL5RVANJAI5F36F2XXBV722I/
#
#
# 標題:國外疫苗二期就EUA？　林氏璧：這是在呼攏！陳時中沒辦法說服我
# 網址:https://tw.appledaily.com//life/20210601/YLSMRJ747RFDNA4TEB3G3DYWZI/
#
#
# 標題:鎖定日本半導體設備！上銀神戶廠動土　投資金額100億日圓
# 網址:https://tw.appledaily.com//property/20210601/BU6SSVZESFB4JFT5CRS74IWVVQ/
#
#
# 標題:彰化疫情｜偷營業還外賣到摩鐵釀8確診　秀妃養生館罰30萬
# 網址:https://tw.appledaily.com//local/20210601/AG22MLVDIJDB3PCODAB6XR4W7I/
#
#
# 標題:玄彬被爆娶孫藝真　卡疫延期明年完婚
# 網址:https://tw.appledaily.com//entertainment/20210601/EH7G5RZR6RG2ZOC2WY2OHVFAUA/
#
#
# 標題:馬祖疫情｜今起入境全面快篩　15項紓困度生計難關
# 網址:https://tw.appledaily.com//life/20210601/IMFAAGUFUNCSTFKEDVI72KIECY/
#
#
# 標題:台股｜高端苦吞第2根跌停！電子航運強　指數開盤漲逾80點 (不斷更新)
# 網址:https://tw.appledaily.com//property/20210601/YUNXSGQU6FBUVD5PAXFYCZNA2A/
#
#
# 標題:國光疫苗輸國外疫苗？權威醫7點打臉　還要郭台銘的BNT「小心這點」
# 網址:https://tw.appledaily.com//life/20210601/YGKCBIM3DREHTLEHXNEZEJVEUA/
#
#
# 標題:紓困4.0啟動！周五開始受理　經濟部預算居各部會首位
# 網址:https://tw.appledaily.com//politics/20210601/M2WQV4MSDNDCZGMVMLAGYQEVJA/
